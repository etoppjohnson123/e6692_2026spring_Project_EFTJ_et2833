# %%
# !pip3 install segmentation-models-pytorch
# Out:
# Collecting segmentation-models-pytorch
#   Downloading https://files.pythonhosted.org/packages/18/31/8211a419a327ba506cc398a68e02e6fa3bf0275161c5f82339f13fbc4009/segmentation_models_pytorch-0.3.1-py3-none-any.whl (102kB)
#     100% |################################| 102kB 2.1MB/s a 0:00:011
# Collecting timm==0.4.12 (from segmentation-models-pytorch)
#   Downloading https://files.pythonhosted.org/packages/90/fc/606bc5cf46acac3aa9bd179b3954433c026aaf88ea98d6b19f5d14c336da/timm-0.4.12-py3-none-any.whl (376kB)
#     100% |################################| 378kB 803kB/s eta 0:00:01
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.6/dist-packages/torchvision-0.10.0a0+300a8a4-py3.6-linux-aarch64.egg (from segmentation-models-pytorch)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch)
#   Downloading https://files.pythonhosted.org/packages/84/0e/be6a0e58447ac16c938799d49bfb5fb7a80ac35e137547fc6cee2c08c4cf/pretrainedmodels-0.7.4.tar.gz (58kB)
#     100% |################################| 61kB 2.4MB/s eta 0:00:01
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch)
#   Downloading https://files.pythonhosted.org/packages/2e/a0/dd40b50aebf0028054b6b35062948da01123d7be38d08b6b1e5435df6363/efficientnet_pytorch-0.7.1.tar.gz
# Collecting tqdm (from segmentation-models-pytorch)
#   Downloading https://files.pythonhosted.org/packages/47/bb/849011636c4da2e44f1253cd927cfb20ada4374d8b3a4e425416e84900cc/tqdm-4.64.1-py2.py3-none-any.whl (78kB)
#     100% |################################| 81kB 2.5MB/s eta 0:00:01
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages/Pillow-8.3.1-py3.6-linux-aarch64.egg (from segmentation-models-pytorch)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.6/dist-packages (from timm==0.4.12->segmentation-models-pytorch)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch)
#   Downloading https://files.pythonhosted.org/packages/56/b3/7c69b37f03260a061883bec0e7b05be7117c1b1c85f5212c72c8c2bc3c8c/munch-4.0.0-py2.py3-none-any.whl
# Collecting importlib-resources; python_version < "3.7" (from tqdm->segmentation-models-pytorch)
#   Downloading https://files.pythonhosted.org/packages/24/1b/33e489669a94da3ef4562938cd306e8fa915e13939d7b8277cb5569cb405/importlib_resources-5.4.0-py3-none-any.whl
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->timm==0.4.12->segmentation-models-pytorch)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from torch>=1.4->timm==0.4.12->segmentation-models-pytorch)
# Requirement already satisfied: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.7"->tqdm->segmentation-models-pytorch)
# Building wheels for collected packages: pretrainedmodels, efficientnet-pytorch
#   Running setup.py bdist_wheel for pretrainedmodels ... done
#   Stored in directory: /root/.cache/pip/wheels/69/df/63/62583c096289713f22db605aa2334de5b591d59861a02c2ecd
#   Running setup.py bdist_wheel for efficientnet-pytorch ... done
#   Stored in directory: /root/.cache/pip/wheels/84/27/aa/c46d23c4e8cc72d41283862b1437e0b3ad318417e8ed7d5921
# Successfully built pretrainedmodels efficientnet-pytorch
# Installing collected packages: timm, munch, importlib-resources, tqdm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.7.1 importlib-resources-5.4.0 munch-4.0.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.1 timm-0.4.12 tqdm-4.64.1

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import torch
from pathlib import Path
from PIL import Image
import torchvision.transforms.functional as TF
from torch.utils.data import Dataset
import cv2
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.functional as TF
from torchvision.models.segmentation import fcn_resnet50
import torch.nn as nn
import segmentation_models_pytorch as smp
from tqdm import tqdm
import pandas as pd
import numpy as np
import time

from utils.lichen_dataset import LichenDataset

# %%
device = "cuda"

# %%
test_images = "/workspace/data_HITL/test/test_images"
test_masks = "/workspace/data_HITL/test/test_masks"

# %%
test_dataset = LichenDataset(
    image_dir=test_images,
    mask_dir=test_masks,
    image_size=512
)

test_loader = DataLoader(
    test_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0
)
# Out:
# Number of pairs found: 50

# %%
model = smp.Unet(
    encoder_name="resnet34",
    encoder_weights=None,
    in_channels=3,
    classes=1
)

weights_path = "/workspace/weights_HITL/2unet_resnet34_lichen.pth"

state_dict = torch.load(weights_path, map_location=device)
model.load_state_dict(state_dict)

model = model.to(device)
model.eval()
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
from pathlib import Path

p = Path("/workspace/weights_HITL/2unet_resnet34_lichen.pth")

print("exists:", p.exists())
print("size bytes:", p.stat().st_size if p.exists() else None)
# Out:
# exists: True
# size bytes: 97923355

# %%
# !head -20 /workspace/weights_HITL/2unet_resnet34_lichen.pth
# Out:
# PK2unet_resnet34_lichen/data.pklFB�ccollections
# OrderedDict
# q)Rq(Xencoder.conv1.weightqctorch._utils
# _rebuild_tensor_v2
# q((Xstorageqctorch
# FloatStorage
# qX0qXcuda:0qM�$tQK(K@KKKtq	(K�K1KKtq
# Xencoder.bn1.weightqh((hhX1qXcuda:0qK@tqQKK@�qK�q�h)RqtqRqXencoder.bn1.biasqh((hhX2qXcuda:0qK@tqQKK@�qK�q�h)RqtqRqXencoder.bn1.running_meanq h((hhX3q!Xcuda:0q"K@tq#QKK@�q$K�q%�h)Rq&tq'Rq(Xencoder.bn1.running_varq)h((hhX4q*Xcuda:0q+K@tq,QKK@�q-K�q.�h)Rq/tq0Rq1Xencoder.bn1.num_batches_trackedq2h((hctorch
# LongStorage
# q3X5q4Xcuda:0q5Ktq6QK))�h)Rq7tq8Rq9Xencoder.layer1.0.conv1.weightq:h((hhX6q;Xcuda:0q<M�tq=QK(K@K@KKtq>(M@K	KKtq?�h)Rq@tqARqBXencoder.layer1.0.bn1.weightqCh((hhX7qDXcuda:0qEK@tqFQKK@�qGK�qH�h)RqItqJRqKXencoder.layer1.0.bn1.biasqLh((hhX8qMXcuda:0qNK@tqOQKK@�qPK�qQ�h)RqRtqSRqTX!encoder.layer1.0.bn1.running_meanqUh((hhX9qVXcuda:0qWK@tqXQKK@�qYK�qZ�h)Rq[tq\Rq]X encoder.layer1.0.bn1.running_varq^h((hhX10q_Xcuda:0q`K@tqaQKK@�qbK�qc�h)RqdtqeRqfX(encoder.layer1.0.bn1.num_batches_trackedqgh((hh3X11qhXcuda:0qiKtqjQK))�h)RqktqlRqmXencoder.layer1.0.conv2.weightqnh((hhX12qoXcuda:0qpM�tqqQK(K@K@KKtqr(M@K	KKtqs�h)RqttquRqvXencoder.layer1.0.bn2.weightqwh((hhX13qxXcuda:0qyK@tqzQKK@�q{K�q|�h)Rq}tq~RqXencoder.layer1.0.bn2.biasq�h((hhX14q�Xcuda:0q�K@tq�QKK@�q�K�q��h)Rq�tq�Rq�X!encoder.layer1.0.bn2.running_meanq�h((hhX15q�Xcuda:0q�K@tq�QKK@�q�K�q��h)Rq�tq�Rq�X encoder.layer1.0.bn2.running_varq�h((hhX16q�Xcuda:0q�K@tq�QKK@�q�K�q��h)Rq�tq�Rq�X(encoder.layer1.0.bn2.num_batches_trackedq�h((hh3X17q�Xcuda:0q�Ktq�QK))�h)Rq�tq�Rq�Xencoder.layer1.1.conv1.weightq�h((hhX18q�Xcuda:0q�M�tq�QK(K@K@KKtq�(M@K	KKtq��h)Rq�tq�Rq�Xencoder.layer1.1.bn1.weightq�h((hhX19q�Xcuda:0q�K@tq�QKK@�q�K�q��h)Rq�tq�Rq�Xencoder.layer1.1.bn1.biasq�h((hhX20q�Xcuda:0q�K@tq�QKK@�q�K�q��h)Rq�tq�Rq�X!encoder.layer1.1.bn1.running_meanq�h((hhX21q�Xcuda:0q�K@tq�QKK@�q�K�q��h)Rq�tq�Rq�X encoder.layer1.1.bn1.running_varq�h((hhX22q�Xcuda:0q�K@tq�QKK@�q�K�q��h)Rq�tq�Rq�
�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X encoder.layer2.0.bn2.running_varr�h((hhX52r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X(encoder.layer2.0.bn2.num_batches_trackedr�h((hh3X53r�Xcuda:0r�Ktr�QK))�h)Rr�tr�Rr�X$encoder.layer2.0.downsample.0.weightr�h((hhX54r�Xcuda:0r�M tr�QK(K�K@KKtr�(K@KKKtr��h)Rr�tr�Rr�X$encoder.layer2.0.downsample.1.weightr�h((hhX55r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X"encoder.layer2.0.downsample.1.biasr�h((hhX56r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X*encoder.layer2.0.downsample.1.running_meanr�h((hhX57r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X)encoder.layer2.0.downsample.1.running_varr�h((hhX58r�Xcuda:0rK�trQKK��rK�r�h)RrtrRrX1encoder.layer2.0.downsample.1.num_batches_trackedrh((hh3X59Xcuda:0r	Ktr
# Xencoder.layer2.1.conv1.weightrh((hhX60rXcuda:0rJ@trQK(K�K�KKtr(M�K	KKtr�h)RrtrRrXencoder.layer2.1.bn1.weightrh((hhX61rXcuda:0rK�trQKK��rK�r�h)RrtrRrXencoder.layer2.1.bn1.biasr h((hhX62r!Xcuda:0r"K�tr#QKK��r$K�r%�h)Rr&tr'Rr(X!encoder.layer2.1.bn1.running_meanr)h((hhX63r*Xcuda:0r+K�tr,QKK��r-K�r.�h)Rr/tr0Rr1X encoder.layer2.1.bn1.running_varr2h((hhX64r3Xcuda:0r4K�tr5QKK��r6K�r7�h)Rr8tr9Rr:X(encoder.layer2.1.bn1.num_batches_trackedr;h((hh3X65r<Xcuda:0r=Ktr>QK))�h)Rr?tr@RrAXencoder.layer2.1.conv2.weightrBh((hhX66rCXcuda:0rDJ@trEQK(K�K�KKtrF(M�K	KKtrG�h)RrHtrIRrJXencoder.layer2.1.bn2.weightrKh((hhX67rLXcuda:0rMK�trNQKK��rOK�rP�h)RrQtrRRrSXencoder.layer2.1.bn2.biasrTh((hhX68rUXcuda:0rVK�trWQKK��rXK�rY�h)RrZtr[Rr\X!encoder.layer2.1.bn2.running_meanr]h((hhX69r^Xcuda:0r_K�tr`QKK��raK�rb�h)RrctrdRreX encoder.layer2.1.bn2.running_varrfh((hhX70rgXcuda:0rhK�triQKK��rjK�rk�h)RrltrmRrnX(encoder.layer2.1.bn2.num_batches_trackedroh((hh3X71rpXcuda:0rqKtrrQK))�h)RrstrtRruXencoder.layer2.2.conv1.weightrvh((hhX72rwXcuda:0rxJ@tryQK(K�K�KKtrz(M�K	KKtr{�h)Rr|tr}Rr~Xencoder.layer2.2.bn1.weightrh((hhX73r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�Xencoder.layer2.2.bn1.biasr�h((hhX74r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X!encoder.layer2.2.bn1.running_meanr�h((hhX75r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X encoder.layer2.2.bn1.running_varr�h((hhX76r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X(encoder.layer2.2.bn1.num_batches_trackedr�h((hh3X77r�Xcuda:0r�Ktr�QK))�h)Rr�tr�Rr�Xencoder.layer2.2.conv2.weightr�h((hhX78r�Xcuda:0r�J@tr�QK(K�K�KKtr�(M�K	KKtr��h)Rr�tr�Rr�Xencoder.layer2.2.bn2.weightr�h((hhX79r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�Xencoder.layer2.2.bn2.biasr�h((hhX80r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X!encoder.layer2.2.bn2.running_meanr�h((hhX81r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�X encoder.layer2.2.bn2.running_varr�h((hhX82r�Xcuda:0r�K�tr�QKK��r�K�r��h)Rr�tr�Rr�
�Xcuda:0r�J	tr�QK(MMKKtr�(M	K	KKtr��h)Rr�tr�Rr�Xencoder.layer3.1.bn1.weightr�h((hhX115r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�Xencoder.layer3.1.bn1.biasr�h((hhX116r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X!encoder.layer3.1.bn1.running_meanr�h((hhX117r�Xcuda:0r�MtrQKM�rK�r�h)RrtrRrX encoder.layer3.1.bn1.running_varrh((hhX118rXcuda:0Mtr	QKM�r
# RrX(encoder.layer3.1.bn1.num_batches_trackedrh((hh3X119rXcuda:0rKtrQK))�h)RrtrRrXencoder.layer3.1.conv2.weightrh((hhX120rXcuda:0rJ	trQK(MMKKtr(M	K	KKtr�h)RrtrRrXencoder.layer3.1.bn2.weightrh((hhX121r Xcuda:0r!Mtr"QKM�r#K�r$�h)Rr%tr&Rr'Xencoder.layer3.1.bn2.biasr(h((hhX122r)Xcuda:0r*Mtr+QKM�r,K�r-�h)Rr.tr/Rr0X!encoder.layer3.1.bn2.running_meanr1h((hhX123r2Xcuda:0r3Mtr4QKM�r5K�r6�h)Rr7tr8Rr9X encoder.layer3.1.bn2.running_varr:h((hhX124r;Xcuda:0r<Mtr=QKM�r>K�r?�h)Rr@trARrBX(encoder.layer3.1.bn2.num_batches_trackedrCh((hh3X125rDXcuda:0rEKtrFQK))�h)RrGtrHRrIXencoder.layer3.2.conv1.weightrJh((hhX126rKXcuda:0rLJ	trMQK(MMKKtrN(M	K	KKtrO�h)RrPtrQRrRXencoder.layer3.2.bn1.weightrSh((hhX127rTXcuda:0rUMtrVQKM�rWK�rX�h)RrYtrZRr[Xencoder.layer3.2.bn1.biasr\h((hhX128r]Xcuda:0r^Mtr_QKM�r`K�ra�h)RrbtrcRrdX!encoder.layer3.2.bn1.running_meanreh((hhX129rfXcuda:0rgMtrhQKM�riK�rj�h)RrktrlRrmX encoder.layer3.2.bn1.running_varrnh((hhX130roXcuda:0rpMtrqQKM�rrK�rs�h)RrttruRrvX(encoder.layer3.2.bn1.num_batches_trackedrwh((hh3X131rxXcuda:0ryKtrzQK))�h)Rr{tr|Rr}Xencoder.layer3.2.conv2.weightr~h((hhX132rXcuda:0r�J	tr�QK(MMKKtr�(M	K	KKtr��h)Rr�tr�Rr�Xencoder.layer3.2.bn2.weightr�h((hhX133r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�Xencoder.layer3.2.bn2.biasr�h((hhX134r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X!encoder.layer3.2.bn2.running_meanr�h((hhX135r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X encoder.layer3.2.bn2.running_varr�h((hhX136r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X(encoder.layer3.2.bn2.num_batches_trackedr�h((hh3X137r�Xcuda:0r�Ktr�QK))�h)Rr�tr�Rr�Xencoder.layer3.3.conv1.weightr�h((hhX138r�Xcuda:0r�J	tr�QK(MMKKtr�(M	K	KKtr��h)Rr�tr�Rr�Xencoder.layer3.3.bn1.weightr�h((hhX139r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�Xencoder.layer3.3.bn1.biasr�h((hhX140r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X!encoder.layer3.3.bn1.running_meanr�h((hhX141r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X encoder.layer3.3.bn1.running_varr�h((hhX142r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X(encoder.layer3.3.bn1.num_batches_trackedr�h((hh3X143r�Xcuda:0r�Ktr�QK))�h)Rr�tr�Rr�Xencoder.layer3.3.conv2.weightr�h((hhX144r�Xcuda:0r�J	tr�QK(MMKKtr�(M	K	KKtr��h)Rr�tr�Rr�Xencoder.layer3.3.bn2.weightr�h((hhX145r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�Xencoder.layer3.3.bn2.biasr�h((hhX146r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�RrX!encoder.layer3.3.bn2.running_meanrh((hhX147rXcuda:0rMtrQKM�rK�r�h)RrtRr	X encoder.layer3.3.bn2.running_varr
# QKM�rK�r�h)RrtrRrX(encoder.layer3.3.bn2.num_batches_trackedrh((hh3X149rXcuda:0rKtrQK))�h)RrtrRrXencoder.layer3.4.conv1.weightrh((hhX150rXcuda:0rJ	trQK(MMKKtr(M	K	KKtr�h)Rr tr!Rr"Xencoder.layer3.4.bn1.weightr#h((hhX151r$Xcuda:0r%Mtr&QKM�r'K�r(�h)Rr)tr*Rr+Xencoder.layer3.4.bn1.biasr,h((hhX152r-Xcuda:0r.Mtr/QKM�r0K�r1�h)Rr2tr3Rr4X!encoder.layer3.4.bn1.running_meanr5h((hhX153r6Xcuda:0r7Mtr8QKM�r9K�r:�h)Rr;tr<Rr=X encoder.layer3.4.bn1.running_varr>h((hhX154r?Xcuda:0r@MtrAQKM�rBK�rC�h)RrDtrERrFX(encoder.layer3.4.bn1.num_batches_trackedrGh((hh3X155rHXcuda:0rIKtrJQK))�h)RrKtrLRrMXencoder.layer3.4.conv2.weightrNh((hhX156rOXcuda:0rPJ	trQQK(MMKKtrR(M	K	KKtrS�h)RrTtrURrVXencoder.layer3.4.bn2.weightrWh((hhX157rXXcuda:0rYMtrZQKM�r[K�r\�h)Rr]tr^Rr_Xencoder.layer3.4.bn2.biasr`h((hhX158raXcuda:0rbMtrcQKM�rdK�re�h)RrftrgRrhX!encoder.layer3.4.bn2.running_meanrih((hhX159rjXcuda:0rkMtrlQKM�rmK�rn�h)RrotrpRrqX encoder.layer3.4.bn2.running_varrrh((hhX160rsXcuda:0rtMtruQKM�rvK�rw�h)RrxtryRrzX(encoder.layer3.4.bn2.num_batches_trackedr{h((hh3X161r|Xcuda:0r}Ktr~QK))�h)Rrtr�Rr�Xencoder.layer3.5.conv1.weightr�h((hhX162r�Xcuda:0r�J	tr�QK(MMKKtr�(M	K	KKtr��h)Rr�tr�Rr�Xencoder.layer3.5.bn1.weightr�h((hhX163r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�Xencoder.layer3.5.bn1.biasr�h((hhX164r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X!encoder.layer3.5.bn1.running_meanr�h((hhX165r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X encoder.layer3.5.bn1.running_varr�h((hhX166r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X(encoder.layer3.5.bn1.num_batches_trackedr�h((hh3X167r�Xcuda:0r�Ktr�QK))�h)Rr�tr�Rr�Xencoder.layer3.5.conv2.weightr�h((hhX168r�Xcuda:0r�J	tr�QK(MMKKtr�(M	K	KKtr��h)Rr�tr�Rr�Xencoder.layer3.5.bn2.weightr�h((hhX169r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�Xencoder.layer3.5.bn2.biasr�h((hhX170r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X!encoder.layer3.5.bn2.running_meanr�h((hhX171r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X encoder.layer3.5.bn2.running_varr�h((hhX172r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�X(encoder.layer3.5.bn2.num_batches_trackedr�h((hh3X173r�Xcuda:0r�Ktr�QK))�h)Rr�tr�Rr�Xencoder.layer4.0.conv1.weightr�h((hhX174r�Xcuda:0r�Jtr�QK(MMKKtr�(M	K	KKtr��h)Rr�tr�Rr�Xencoder.layer4.0.bn1.weightr�h((hhX175r�Xcuda:0r�Mtr�QKM�r�K�r��h)Rr�tr�Rr�Xencoder.layer4.0.bn1.biasr�h((hhX176r�Xcuda:0r�Mtr�QKM�rK�r�h)RrtrRrX!encoder.layer4.0.bn1.running_meanrh((hhX177rXcuda:0rMtQKM�r	K�r
# X encoder.layer4.0.bn1.running_varrh((hhX178rXcuda:0rMtrQKM�rK�r�h)RrtrRrX(encoder.layer4.0.bn1.num_batches_trackedrh((hh3X179rXcuda:0rKtrQK))�h)RrtrRrXencoder.layer4.0.conv2.weightrh((hhX180rXcuda:0r J$tr!QK(MMKKtr"(MK	KKtr#�h)Rr$tr%Rr&Xencoder.layer4.0.bn2.weightr'h((hhX181r(Xcuda:0r)Mtr*QKM�r+K�r,�h)Rr-tr.Rr/Xencoder.layer4.0.bn2.biasr0h((hhX182r1Xcuda:0r2Mtr3QKM�r4K�r5�h)Rr6tr7Rr8X!encoder.layer4.0.bn2.running_meanr9h((hhX183r:Xcuda:0r;Mtr<QKM�r
Xcuda:0rK@trQKK@�rK�r�h)RrtrRrX$decoder.blocks.2.conv2.1.running_varrh((hhX250rXcuda:0rK@trQKK@�rK�r�h)RrtrRrX,decoder.blocks.2.conv2.1.num_batches_trackedrh((hh3X251rXcuda:0rKtrQK))�h)RrtrRrXdecoder.blocks.3.conv1.0.weightrh((hhX252rXcuda:0rM�trQK(K K�KKtr(M�K	KKtr�h)RrtrRrXdecoder.blocks.3.conv1.1.weightrh((hhX253rXcuda:0rK trQKK �rK�r�h)RrtrRrXdecoder.blocks.3.conv1.1.biasrh((hhX254rXcuda:0rK trQKK �rK�r�h)RrtrRrX%decoder.blocks.3.conv1.1.running_meanrh((hhX255rXcuda:0rK trQKK �rK�r�h)RrtrRrX$decoder.blocks.3.conv1.1.running_varrh((hhX256rXcuda:0rK trQKK �rK�r�h)RrtrRrX,decoder.blocks.3.conv1.1.num_batches_trackedrh((hh3X257rXcuda:0rKtrQK))�h)RrtrRrXdecoder.blocks.3.conv2.0.weightrh((hhX258rXcuda:0rM$trQK(K K KKtr(M K	KKtr�h)RrtrRrXdecoder.blocks.3.conv2.1.weightrh((hhX259rXcuda:0rK trQKK �rK�r�h)RrtrRrXdecoder.blocks.3.conv2.1.biasrh((hhX260rXcuda:0rK trQKK �rK�r�h)RrtrRrX%decoder.blocks.3.conv2.1.running_meanrh((hhX261rXcuda:0rK trQKK �rK�r�h)RrtrRrX$decoder.blocks.3.conv2.1.running_varrh((hhX262rXcuda:0rK trQKK �rK�r�h)RrtrRrX,decoder.blocks.3.conv2.1.num_batches_trackedrh((hh3X263rXcuda:0rKtrQK))�h)RrtrRrXdecoder.blocks.4.conv1.0.weightrh((hhX264rXcuda:0rMtrQK(KK KKtr(M K	KKtr�h)RrtrRrXdecoder.blocks.4.conv1.1.weightrh((hhX265r	Xcuda:0r	Ktr	QKK�r	K�r	�h)Rr	tr	Rr	Xdecoder.blocks.4.conv1.1.bias	h((hhX266r		Xcuda:0r
# encoder.conv1rx	}ry	ju	KsXencoder.bn1rz	}r{	ju	KsXencoder.relur|	}r}	ju	KsXencoder.maxpoolr~	}r	ju	KsXencoder.layer1r�	}r�	ju	KsXencoder.layer1.0r�	}r�	ju	KsXencoder.layer1.0.conv1r�	}r�	ju	KsXencoder.layer1.0.bn1r�	}r�	ju	KsXencoder.layer1.0.relur�	}r�	ju	KsXencoder.layer1.0.conv2r�	}r�	ju	KsXencoder.layer1.0.bn2r�	}r�	ju	KsXencoder.layer1.1r�	}r�	ju	KsXencoder.layer1.1.conv1r�	}r�	ju	KsXencoder.layer1.1.bn1r�	}r�	ju	KsXencoder.layer1.1.relur�	}r�	ju	KsXencoder.layer1.1.conv2r�	}r�	ju	KsXencoder.layer1.1.bn2r�	}r�	ju	KsXencoder.layer1.2r�	}r�	ju	KsXencoder.layer1.2.conv1r�	}r�	ju	KsXencoder.layer1.2.bn1r�	}r�	ju	KsXencoder.layer1.2.relur�	}r�	ju	KsXencoder.layer1.2.conv2r�	}r�	ju	KsXencoder.layer1.2.bn2r�	}r�	ju	KsXencoder.layer2r�	}r�	ju	KsXencoder.layer2.0r�	}r�	ju	KsXencoder.layer2.0.conv1r�	}r�	ju	KsXencoder.layer2.0.bn1r�	}r�	ju	KsXencoder.layer2.0.relur�	}r�	ju	KsXencoder.layer2.0.conv2r�	}r�	ju	KsXencoder.layer2.0.bn2r�	}r�	ju	KsXencoder.layer2.0.downsampler�	}r�	ju	KsXencoder.layer2.0.downsample.0r�	}r�	ju	KsXencoder.layer2.0.downsample.1r�	}r�	ju	KsXencoder.layer2.1r�	}r�	ju	KsXencoder.layer2.1.conv1r�	}r�	ju	KsXencoder.layer2.1.bn1r�	}r�	ju	KsXencoder.layer2.1.relur�	}r�	ju	KsXencoder.layer2.1.conv2r�	}r�	ju	KsXencoder.layer2.1.bn2r�	}r�	ju	KsXencoder.layer2.2r�	}r�	ju	KsXencoder.layer2.2.conv1r�	}r�	ju	KsXencoder.layer2.2.bn1r�	}r�	ju	KsXencoder.layer2.2.relur�	}r�	ju	KsXencoder.layer2.2.conv2r�	}r�	ju	KsXencoder.layer2.2.bn2r�	}r�	ju	KsXencoder.layer2.3r�	}r�	ju	KsXencoder.layer2.3.conv1r�	}r�	ju	KsXencoder.layer2.3.bn1r�	}r�	ju	KsXencoder.layer2.3.relur�	}r�	ju	KsXencoder.layer2.3.conv2r�	}r�	ju	KsXencoder.layer2.3.bn2r�	}r�	ju	KsXencoder.layer3r�	}r�	ju	KsXencoder.layer3.0r�	}r�	ju	KsXencoder.layer3.0.conv1r�	}r�	ju	KsXencoder.layer3.0.bn1r�	}r�	ju	KsXencoder.layer3.0.relur�	}r�	ju	KsXencoder.layer3.0.conv2r�	}r�	ju	KsXencoder.layer3.0.bn2r�	}r�	ju	KsXencoder.layer3.0.downsampler�	}r�	ju	KsXencoder.layer3.0.downsample.0r�	}r�	ju	KsXencoder.layer3.0.downsample.1r�	}r�	ju	KsXencoder.layer3.1r�	}r�	ju	KsXencoder.layer3.1.conv1r�	}r�	ju	KsXencoder.layer3.1.bn1r�	}r�	ju	KsXencoder.layer3.1.relur�	}r�	ju	KsXencoder.layer3.1.conv2r�	}r�	ju	KsXencoder.layer3.1.bn2r�	}r�	ju	KsXencoder.layer3.2r�	}r�	ju	KsXencoder.layer3.2.conv1r
# }r

# %%
def compute_metrics(pred, mask, eps=1e-7):
    pred = pred.bool()
    mask = mask.bool()

    tp = (pred & mask).sum().item()
    fp = (pred & ~mask).sum().item()
    fn = (~pred & mask).sum().item()
    tn = (~pred & ~mask).sum().item()

    iou = tp / (tp + fp + fn + eps)
    dice = (2 * tp) / (2 * tp + fp + fn + eps)
    precision = tp / (tp + fp + eps)
    recall = tp / (tp + fn + eps)
    accuracy = (tp + tn) / (tp + tn + fp + fn + eps)

    return {
        "iou": iou,
        "dice": dice,
        "precision": precision,
        "recall": recall,
        "accuracy": accuracy
    }

# %%
all_metrics = []
latencies = []

threshold = 0.5

with torch.no_grad():
    for images, masks, names in test_loader:
        images = images.to(device)
        masks = masks.to(device)

        if device == "cuda":
            torch.cuda.synchronize()

        start = time.time()

        logits = model(images)
        probs = torch.sigmoid(logits)
        preds = probs > threshold

        if device == "cuda":
            torch.cuda.synchronize()

        end = time.time()

        latency = end - start
        latencies.append(latency)

        metrics = compute_metrics(preds.cpu(), masks.cpu())
        metrics["filename"] = names[0]
        metrics["latency_sec"] = latency

        all_metrics.append(metrics)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /media/nvidia/NVME/pytorch/pytorch-v1.9.0/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
df = pd.DataFrame(all_metrics)
df.head()
# Out:
#         iou      dice  precision    recall  accuracy          filename  \
# 0  0.647281  0.785878   0.661604  0.967637  0.834488   lichen_11032703
# 1  0.626725  0.770536   0.888994  0.679935  0.757782  lichen_297012592
# 2  0.808863  0.894333   0.879308  0.909880  0.830902  lichen_265585502
# 3  0.122150  0.217706   0.135164  0.559200  0.670471   lichen_74735136
# 4  0.604928  0.753838   0.818581  0.698587  0.816399  lichen_181096723
#
#    latency_sec
# 0    80.673636
# 1     2.058166
# 2     1.591047
# 3     0.543719
# 4     0.443502

# %%
latencies_ms = [x * 1000 for x in latencies]

plt.figure(figsize=(10,5))

plt.plot(latencies_ms)

plt.xlabel("Test Image Index")
plt.ylabel("Latency (ms)")
plt.title("Inference Latency per Image")

plt.grid(True)

plt.show()

# %%
df.mean(numeric_only=True)
# Out:
# iou            0.583038
# dice           0.709376
# precision      0.706438
# recall         0.789681
# accuracy       0.829701
# latency_sec    2.106674
# dtype: float64

# %%
df
# Out:
#          iou      dice  precision    recall  accuracy          filename  \
# 0   0.647281  0.785878   0.661604  0.967637  0.834488   lichen_11032703
# 1   0.626725  0.770536   0.888994  0.679935  0.757782  lichen_297012592
# 2   0.808863  0.894333   0.879308  0.909880  0.830902  lichen_265585502
# 3   0.122150  0.217706   0.135164  0.559200  0.670471   lichen_74735136
# 4   0.604928  0.753838   0.818581  0.698587  0.816399  lichen_181096723
# 5   0.398007  0.569392   0.632323  0.517853  0.870716   lichen_41813255
# 6   0.791078  0.883354   0.800006  0.986090  0.914799  lichen_141767571
# 7   0.426009  0.597484   0.860583  0.457589  0.705006   lichen_34608861
# 8   0.541618  0.702662   0.585000  0.879571  0.824356   lichen_93036882
# 9   0.865180  0.927717   0.911427  0.944601  0.922249   lichen_37456823
# 10  0.803962  0.891329   0.982760  0.815464  0.856945  lichen_196498842
# 11  0.668912  0.801614   0.676311  0.983907  0.903606  lichen_193286219
# 12  0.315831  0.480048   0.447007  0.518363  0.801723   lichen_83362056
# 13  0.420755  0.592298   0.897181  0.442072  0.669605   lichen_33879758
# 14  0.308494  0.471526   0.314654  0.940329  0.867676  lichen_244332135
# 15  0.648032  0.786432   0.657743  0.977726  0.719883   lichen_31838609
# 16  0.102989  0.186745   0.103245  0.976493  0.599735  lichen_141767570
# 17  0.550925  0.710447   0.969259  0.560723  0.963333  lichen_334207272
# 18  0.402515  0.573990   0.743334  0.467488  0.668819  lichen_192805009
# 19  0.426628  0.598093   0.512051  0.718892  0.676945  lichen_181200559
# 20  0.002097  0.004186   0.286426  0.002108  0.582531  lichen_164885398
# 21  0.613213  0.760238   0.694767  0.839333  0.881969  lichen_108868426
# 22  0.372147  0.542431   0.437866  0.712604  0.814140  lichen_245919386
# 23  0.592817  0.744363   0.705863  0.787305  0.939713  lichen_343644931
# 24  0.565869  0.722754   0.578105  0.963944  0.942726  lichen_141700029
# 25  0.857936  0.923537   0.897305  0.951349  0.957645  lichen_141768028
# 26  0.731510  0.844939   0.983460  0.740621  0.738010  lichen_297012580
# 27  0.813366  0.897078   0.824573  0.983564  0.908283  lichen_112551132
# 28  0.736605  0.848328   0.764920  0.952152  0.963600  lichen_215959497
# 29  0.709928  0.830360   0.710238  0.999385  0.939243   lichen_11032781
# 30  0.742576  0.852274   0.772317  0.950699  0.895039  lichen_215959491
# 31  0.601383  0.751079   0.649380  0.890549  0.823174   lichen_87993611
# 32  0.589688  0.741891   0.934546  0.615092  0.772385  lichen_189138964
# 33  0.566724  0.723451   0.598426  0.914515  0.662136  lichen_189772930
# 34  0.896466  0.945407   0.928542  0.962896  0.912388  lichen_290609661
# 35  0.422954  0.594473   0.458377  0.845512  0.821205   lichen_33787774
# 36  0.493962  0.661278   0.795302  0.565911  0.957001    lichen_6371736
# 37  0.804661  0.891758   0.820183  0.977020  0.868061   lichen_10830319
# 38  0.211698  0.349424   0.484233  0.273330  0.882214   lichen_84184685
# 39  0.640257  0.780679   0.952474  0.661386  0.933247  lichen_140255568
# 40  0.841858  0.914140   0.849583  0.989315  0.942478  lichen_139989370
# 41  0.837728  0.911699   0.858563  0.971847  0.955719  lichen_141768016
# 42  0.204337  0.339335   0.205207  0.979660  0.631561  lichen_141459500
# 43  0.680037  0.809550   0.932081  0.715492  0.807777   lichen_39757623
# 44  0.798187  0.887769   1.000000  0.798187  0.798187  lichen_193328829
# 45  0.681433  0.810538   0.687268  0.987694  0.853291  lichen_228976657
# 46  0.745045  0.853898   0.823508  0.886617  0.867504   lichen_58674519
# 47  0.580905  0.734902   0.643793  0.856049  0.821819  lichen_133114940
# 48  0.661742  0.796444   0.672700  0.975974  0.805939   lichen_31838572
# 49  0.673906  0.805190   0.895346  0.731529  0.930641   lichen_70730222
#
#     latency_sec
# 0     80.673636
# 1      2.058166
# 2      1.591047
# 3      0.543719
# 4      0.443502
# 5      0.445034
# 6      0.444308
# 7      0.444633
# 8      0.445305
# 9      0.443477
# 10     0.444465
# 11     0.445868
# 12     0.443739
# 13     0.444319
# 14     0.444837
# 15     0.443563
# 16     0.444416
# 17     0.444355
# 18     0.444156
# 19     0.446573
# 20     0.445401
# 21     0.444116
# 22     0.445289
# 23     0.445458
# 24     0.445105
# 25     0.445855
# 26     0.446190
# 27     0.445058
# 28     0.445903
# 29     0.444228
# 30     0.445864
# 31     0.443654
# 32     0.446088
# 33     0.445909
# 34     0.445448
# 35     0.444790
# 36     0.444824
# 37     0.444468
# 38     0.445011
# 39     0.444549
# 40     0.445840
# 41     0.444916
# 42     0.443779
# 43     0.444431
# 44     0.445757
# 45     0.444392
# 46     0.446589
# 47     0.444874
# 48     0.444734
# 49     0.446059
